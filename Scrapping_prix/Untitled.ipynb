# %%
import pandas as pd

import numpy as np

# %%
data = pd.read_csv('prix_vente.csv',",")
data
# Out:
#     nom_commune prix_appartement_bas_m2_vente prix_appartement_haut_m2_vente  \
# 0     Montreuil                        5250.0                        7793.34
# 1     Montreuil                       3495.34                        4390.24
# 2     Montreuil                       1933.12                        2598.89
# 3     Montreuil                        4500.0                         7500.0
# 4     Montreuil                       4264.71                        7493.28
# 5     Montreuil                       1854.29                        7150.75
# 6     Montreuil                       1842.11                        7140.81
# 7     Montreuil                       5195.95                        7676.67
# 8     Montreuil                       1809.09                        7083.33
# 9     Montreuil                       1777.74                        7083.33
# 10    Montreuil                       1740.84                        7036.36
# ...

# %%
len(np.unique(list(data["nom_commune"])))
# Out:
# 40

# %%
data[data["prix_appartement_moyen_m2_vente"]=="NC"]
# Out:
# Empty DataFrame
# Columns: [nom_commune, prix_appartement_bas_m2_vente, prix_appartement_haut_m2_vente, prix_appartement_moyen_m2_vente, prix_maison_bas_m2_vente, prix_maison_haut_m2_vente, prix_maison_moyen_m2_vente]
# Index: []
